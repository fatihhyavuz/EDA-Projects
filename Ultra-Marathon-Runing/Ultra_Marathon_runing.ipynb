# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\Fatih YAVUZ\AppData\Local\Temp\ipykernel_21824\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df_copy = df.copy()

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7461195 entries, 0 to 7461194
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 740.0+ MB

# %%
df['Event distance/length'].unique()
# Out:
# array(['50km', '6h', '63.9km', ..., '2925.7mi/64Etappen',
#        '355km/5Etappen', '2906.1mi/64Etappen'], dtype=object)

# %%
# 50km 
df[df['Event distance/length']== '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# 50mi
df[df['Event distance/length']== '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
# 50km and 50 mi races

# %%
df[df['Event distance/length'].isin(['50mi','50km'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# 50mi and 50km races in 2020

# %%
df[(df['Event distance/length'].isin(['50mi','50km'])) & (df['Year of event']== 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
# races in usa

# %%
df[df['Event name'].str.split("(").str.get(1).str.split(")").str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
# 50mi, 50 km races in usa in 2020

# %%
df[(df['Event name'].str.split("(").str.get(1).str.split(")").str.get(0) == 'USA') & (df['Event distance/length'].isin(['50mi','50km'])) & (df['Year of event']== 2020)]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
# creating a new df which hold record of 50km and 50 mi races in usa in 2020 (df2)

# %%
df2 = df[(df['Event name'].str.split("(").str.get(1).str.split(")").str.get(0) == 'USA') & (df['Event distance/length'].isin(['50mi','50km'])) & (df['Year of event']== 2020)]

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %%
# removing (USA) from event name

# %%
df2["Event name"].str.split("(").str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
df2["Event name"] = df2["Event name"].str.split("(").str.get(0)
# Out:
# C:\Users\Fatih YAVUZ\AppData\Local\Temp\ipykernel_21824\3464257636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Event name"] = df2["Event name"].str.split("(").str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
# age

# %%
df2['athlete_age'] = 2020 - df2['Athlete year of birth']
# Out:
# C:\Users\Fatih YAVUZ\AppData\Local\Temp\ipykernel_21824\3897931444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = 2020 - df2['Athlete year of birth']

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(" ").str.get(0)
# Out:
# C:\Users\Fatih YAVUZ\AppData\Local\Temp\ipykernel_21824\4285507021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(" ").str.get(0)

# %%
df2.sample()
# Out:
#          Year of event Event dates            Event name  \
# 2662258           2020  12.09.2020  Dam Yeti 50 km Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2662258                  50km                         65             6:15:41
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 2662258  *Butler, OH             USA                 1972.0              M
#
#         Athlete age category Athlete average speed  Athlete ID  athlete_age
# 2662258                  M45                 7.985      199586         48.0

# %%
# droping columns

# %%
df2.drop(columns= ['Athlete club','Athlete year of birth','Athlete country','Athlete age category'], inplace=True)
# Out:
# C:\Users\Fatih YAVUZ\AppData\Local\Temp\ipykernel_21824\3494794336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns= ['Athlete club','Athlete year of birth','Athlete country','Athlete age category'], inplace=True)

# %%
    df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
# null values

# %%
df2.isnull().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  233
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.isnull().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# athlete_age                  0
# dtype: int64

# %%
df2.reset_index(drop =True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# renaming columns

# %%
df2 = df2.rename(columns={'Year of event': 'year_of_event' ,
                          'Event dates': 'event_dates' ,
                          'Event name':'event_name' ,
                          'Event distance/length': 'event_lenght',
                          'Event number of finishers' :'event_number_of_finishers',
                          'Athlete performance': 'athlete_performance',
                          'Athlete gender': 'athlete_gender',
                          'Athlete average speed':'athlete_average_speed',
                          'Athlete ID':'athlete_id'})

# %%
df2.head()
# Out:
#          year_of_event event_dates                                event_name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         event_lenght  event_number_of_finishers athlete_performance  \
# 2539945         50km                         20             3:17:55
# 2539946         50km                         20             4:02:32
# 2539947         50km                         20             4:07:57
# 2539948         50km                         20             4:22:02
# 2539949         50km                         20             4:27:34
#
#         athlete_gender athlete_average_speed  athlete_id  athlete_age
# ...

# %%
# duplicate

# %%
df2.duplicated().sum() # 0
# Out:
# 0

# %%
df2[df2.duplicated() == True] # 0
# Out:
# Empty DataFrame
# Columns: [year_of_event, event_dates, event_name, event_lenght, event_number_of_finishers, athlete_performance, athlete_gender, athlete_average_speed, athlete_id, athlete_age]
# Index: []

# %%
# dtypes

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)

# %%
df2['athlete_average_speed'] = df2['athlete_average_speed'].astype(float)

# %%
# df2['Event dates'] = pd.to_datetime(df2['Event dates'],errors='coerce', dayfirst=True)

# %%
df2.dtypes
# Out:
# year_of_event                  int64
# event_dates                   object
# event_name                    object
# event_lenght                  object
# event_number_of_finishers      int64
# athlete_performance           object
# athlete_gender                object
# athlete_average_speed        float64
# athlete_id                     int64
# athlete_age                    int32
# dtype: object

# %%
# reordering columns

# %%
df3 = df2[['event_name','event_dates','event_lenght','year_of_event','event_number_of_finishers','athlete_performance','athlete_average_speed','athlete_age','athlete_gender','athlete_id']]

# %%
df3.head()
# Out:
#                                        event_name event_dates event_lenght  \
# 2539945  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539946  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539947  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539948  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539949  West Seattle Beach Run - Winter Edition   02.02.2020         50km
#
#          year_of_event  event_number_of_finishers athlete_performance  \
# 2539945           2020                         20             3:17:55
# 2539946           2020                         20             4:02:32
# 2539947           2020                         20             4:07:57
# 2539948           2020                         20             4:22:02
# 2539949           2020                         20             4:27:34
#
#          athlete_average_speed  athlete_age athlete_gender  athlete_id
# ...

# %%
sns.histplot(data = df3, x= "event_lenght")
plt.show()

# %%
sns.histplot(data = df3, x= "event_lenght", hue= "athlete_gender")
plt.show()

# %%
sns.displot(df3[df3["event_lenght"] == "50mi"]["athlete_average_speed"]);

# %%
sns.displot(df3[df3["event_lenght"] == "50km"]["athlete_average_speed"]);

# %%
sns.violinplot(data = df3, x = "event_lenght", y="athlete_average_speed", hue = "athlete_gender", split = True, inner = "quart" ) ;

# %%
sns.lmplot(data = df3, x = "athlete_age", y="athlete_average_speed", hue = "athlete_gender");

# %%
df3.groupby(["event_lenght","athlete_gender"])["athlete_average_speed"].mean()
# Out:
# event_lenght  athlete_gender
# 50km          F                 7.083011
#               M                 7.738985
# 50mi          F                 6.834371
#               M                 7.257633
# Name: athlete_average_speed, dtype: float64

# %%
# the best age groups ın 50mı

# %%
df3.query("event_lenght == '50mi'").groupby("athlete_age")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean",ascending = False).query('count > 19')
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182
# 40           7.310669    236
# 21           7.304658     38
# 20           7.293778     27
# 32           7.287969    162
# 39           7.283648    227
# 37           7.220493    221
# 27           7.201748    119
# 41           7.197017    179
# 45           7.130667    156
# 47           7.085410    156
# 44           7.052642    179
# 51           7.019379    124
# 46           6.897236    174
# 43           6.884225    187
# 52           6.847400    130
# ...

# %%
# the worst age groups ın 50mı

# %%
df3.query("event_lenght == '50mi'").groupby("athlete_age")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean",ascending = True).query('count > 19')
# Out:
#                  mean  count
# athlete_age
# 60           6.261788     33
# 62           6.272730     37
# 61           6.358355     31
# 63           6.514806     31
# 58           6.582328     67
# 64           6.620727     22
# 50           6.671541    172
# 59           6.672072     83
# 48           6.696853    136
# 56           6.708373     67
# 53           6.736969     96
# 57           6.783205     78
# 49           6.789553    159
# 54           6.805506     83
# 55           6.828623     69
# 52           6.847400    130
# 43           6.884225    187
# 46           6.897236    174
# 51           7.019379    124
# 44           7.052642    179
# 47           7.085410    156
# 45           7.130667    156
# 41           7.197017    179
# 27           7.201748    119
# 37           7.220493    221
# 39           7.283648    227
# 32           7.287969    162
# 20           7.293778     27
# 21           7.304658     38
# 40           7.310669    236
# ...

# %%
df3["event_month"] = df3["event_dates"].str.split(".").str.get(1).astype(int)
# Out:
# C:\Users\Fatih YAVUZ\AppData\Local\Temp\ipykernel_21824\836926108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["event_month"] = df3["event_dates"].str.split(".").str.get(1).astype(int)

# %%
df3.head()
# Out:
#                                        event_name event_dates event_lenght  \
# 2539945  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539946  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539947  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539948  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539949  West Seattle Beach Run - Winter Edition   02.02.2020         50km
#
#          year_of_event  event_number_of_finishers athlete_performance  \
# 2539945           2020                         20             3:17:55
# 2539946           2020                         20             4:02:32
# 2539947           2020                         20             4:07:57
# 2539948           2020                         20             4:22:02
# 2539949           2020                         20             4:27:34
#
#          athlete_average_speed  athlete_age athlete_gender  athlete_id  \
# ...

# %%
df3["event_season"] = df3["event_month"].apply(
    lambda x: "winter" if x in [12, 1, 2] else
              "spring" if x in [3, 4, 5] else
              "summer" if x in [6, 7, 8] else
              "fall" )
# Out:
# C:\Users\Fatih YAVUZ\AppData\Local\Temp\ipykernel_21824\1275091133.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["event_season"] = df3["event_month"].apply(

# %%
df3.head()
# Out:
#                                        event_name event_dates event_lenght  \
# 2539945  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539946  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539947  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539948  West Seattle Beach Run - Winter Edition   02.02.2020         50km
# 2539949  West Seattle Beach Run - Winter Edition   02.02.2020         50km
#
#          year_of_event  event_number_of_finishers athlete_performance  \
# 2539945           2020                         20             3:17:55
# 2539946           2020                         20             4:02:32
# 2539947           2020                         20             4:07:57
# 2539948           2020                         20             4:22:02
# 2539949           2020                         20             4:27:34
#
#          athlete_average_speed  athlete_age athlete_gender  athlete_id  \
# ...

# %%
df3.groupby("event_season")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean",ascending = False)
# Out:
#                   mean  count
# event_season
# spring        7.684430   3294
# winter        7.608751  10361
# fall          7.322771   9549
# summer        6.869336   2653

# %%
mean_speeds = df3.groupby("event_season")["athlete_average_speed"].mean().reset_index()
mean_speeds
# Out:
#   event_season  athlete_average_speed
# 0         fall               7.322771
# 1       spring               7.684430
# 2       summer               6.869336
# 3       winter               7.608751

# %%
sns.barplot(x="event_season", y="athlete_average_speed", data=mean_speeds);
